# %%
import os
import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine, text

load_dotenv()

# DB 접속 정보 설정
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT", 3306)
DB_DATABASE = os.getenv("DB_DATABASE")

BASE_DB_URL = f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}"
TARGET_DB_URL = f"{BASE_DB_URL}/{DB_DATABASE}"

# 인덱스의 활용
engine = create_engine(TARGET_DB_URL)
query = "select * from trending_snapshots where category_id = 10;"
df = pd.read_sql(query, engine)
df
# Out:
#            video_id  event_id     collection_date   rank  view_count  \
# 0       __Ys6bXwRpM         1 2022-09-30 09:00:00   21.0    240438.0
# 1       __Ys6bXwRpM         1 2022-09-30 15:00:00   26.0    251474.0
# 2       __Ys6bXwRpM         1 2022-09-30 21:00:00   33.0    259412.0
# 3       __Ys6bXwRpM         2 2022-10-04 21:00:00   61.0    703190.0
# 4       __Ys6bXwRpM         2 2022-10-05 03:00:00   61.0    933862.0
# ...             ...       ...                 ...    ...         ...
# 107405  zzKV_T9ybe8         2 2024-01-08 21:00:00  174.0  11813313.0
# 107406  zzKV_T9ybe8         2 2024-01-09 03:00:00  174.0  11874281.0
# 107407  zzKV_T9ybe8         2 2024-01-09 09:00:00  175.0  11924781.0
# 107408  zzKV_T9ybe8         2 2024-01-09 15:00:00  196.0  11965035.0
# 107409  zzKV_T9ybe8         3 2024-01-10 03:00:00  199.0  12119269.0
#
#         comment_count  category_id category_group                channel_id  \
# 0               315.0           10          Music  UC6YMr57knEIYXOOKMmYAFXQ
# 1               336.0           10          Music  UC6YMr57knEIYXOOKMmYAFXQ
# 2               358.0           10          Music  UC6YMr57knEIYXOOKMmYAFXQ
# 3               435.0           10          Music  UC6YMr57knEIYXOOKMmYAFXQ
# 4               438.0           10          Music  UC6YMr57knEIYXOOKMmYAFXQ
# ...               ...          ...            ...                       ...
# 107405       123911.0           10          Music  UC3IZKseVpdzPSBaWxBxundA
# 107406       124026.0           10          Music  UC3IZKseVpdzPSBaWxBxundA
# 107407       124115.0           10          Music  UC3IZKseVpdzPSBaWxBxundA
# 107408       124200.0           10          Music  UC3IZKseVpdzPSBaWxBxundA
# 107409       124451.0           10          Music  UC3IZKseVpdzPSBaWxBxundA
#
#               published_at                                      title
# 0      2022-09-29 23:00:17         BE'O (비오) - '자격지심 (Feat. ZICO)' MV
# 1      2022-09-29 23:00:17         BE'O (비오) - '자격지심 (Feat. ZICO)' MV
# 2      2022-09-29 23:00:17         BE'O (비오) - '자격지심 (Feat. ZICO)' MV
# 3      2022-09-29 23:00:17         BE'O (비오) - '자격지심 (Feat. ZICO)' MV
# 4      2022-09-29 23:00:17         BE'O (비오) - '자격지심 (Feat. ZICO)' MV
# ...                    ...                                        ...
# 107405 2023-12-22 20:00:02  지민 (Jimin) 'Closer Than This' Official MV
# 107406 2023-12-22 20:00:02  지민 (Jimin) 'Closer Than This' Official MV
# 107407 2023-12-22 20:00:02  지민 (Jimin) 'Closer Than This' Official MV
# 107408 2023-12-22 20:00:02  지민 (Jimin) 'Closer Than This' Official MV
# 107409 2023-12-22 20:00:02  지민 (Jimin) 'Closer Than This' Official MV
#
# [107410 rows x 11 columns]
